# %% [markdown]
# Author: Caio Moreno <BR>
# Version: 15 April 2021 <BR>
#
# This notebook convert all audio files into the data folder to text <BR>

# %%
# Author: Caio Moreno 

# Import Python Libraries
import glob
import azure.cognitiveservices.speech as speechsdk
import time
import json
import pandas as pd

# Create a config file with your own configuration
config_file_name = "config/config_file_dev.json"

with open(config_file_name, 'r') as json_data_file:
    configuration = json.load(json_data_file)

print("################################")
#print(configuration)
print("################################")

# Speech SDK
speech_key = configuration["speech_api"]["speech_key"]
service_region = configuration["speech_api"]["service_region"]

# File location
location = configuration["location"]["full_file_path"]

print ("####################################################################################")
#print("speech_key: " + speech_key)
print("service_region: " + service_region)
print("full_file_path: " + location)
print ("####################################################################################")
print ("IMPORTANT!!!")
print ("Please change the config/config_file_dev.json with your Azure Credentials and folder path!!!")
print ("IMPORTANT!!!")
print ("####################################################################################")
# Out:
# ################################
# ################################
# ####################################################################################
# service_region: uksouth
# full_file_path: data
# ####################################################################################
# IMPORTANT!!!
# Please change the config/config_file_dev.json with your Azure Credentials and folder path!!!
# IMPORTANT!!!
# ####################################################################################

# %%
# Creates an instance of a speech config with specified subscription key and service region.
# Replace with your own subscription key and region identifier from here: https://aka.ms/speech/sdkregion
speech_key, service_region = speech_key, service_region
speech_config = speechsdk.SpeechConfig(subscription=speech_key, region=service_region)

print ("####################################################################################")
print ("PROGRAM START")
print ("####################################################################################")

def speech_recognize_continuous_from_file(file):
    """performs continuous speech recognition with input from an audio file"""
    # <SpeechContinuousRecognitionWithFile>
    speech_config = speechsdk.SpeechConfig(subscription=speech_key, region=service_region)
    audio_config = speechsdk.audio.AudioConfig(filename=file)

    speech_recognizer = speechsdk.SpeechRecognizer(speech_config=speech_config, audio_config=audio_config)

    done = False

    def stop_cb(evt):
        """callback that stops continuous recognition upon receiving an event `evt`"""
        print('CLOSING on {}'.format(evt))
        speech_recognizer.stop_continuous_recognition()
        nonlocal done
        done = True

    all_results = []
    def handle_final_result(evt):
        all_results.append(evt.result.text)

    speech_recognizer.recognized.connect(handle_final_result)
    # Connect callbacks to the events fired by the speech recognizer
    speech_recognizer.recognizing.connect(lambda evt: print('RECOGNIZING: {}'.format(evt)))
    speech_recognizer.recognized.connect(lambda evt: print('RECOGNIZED: {}'.format(evt)))
    speech_recognizer.session_started.connect(lambda evt: print('SESSION STARTED: {}'.format(evt)))
    speech_recognizer.session_stopped.connect(lambda evt: print('SESSION STOPPED {}'.format(evt)))
    speech_recognizer.canceled.connect(lambda evt: print('CANCELED {}'.format(evt)))
    # stop continuous recognition on either session stopped or canceled events
    speech_recognizer.session_stopped.connect(stop_cb)
    speech_recognizer.canceled.connect(stop_cb)

    # Start continuous speech recognition
    speech_recognizer.start_continuous_recognition()
    while not done:
        time.sleep(.5)

    print("Printing all results:")
    print(all_results)

    df = pd.DataFrame(all_results)
    df

    file_name = file + r"-speech-to-text-csv-output.csv"
    df.to_csv(file_name)


    print ("Audio File: "+file+" converted successfully")
    print ("####################################################################################")


# Define the files locations and list audio files (*.wav)
#location = 'C:\\Users\\camoren\\Documents\\GitHub\\Microsoft-Cognitive-Services\\speech-to-text\\data'
location = location

fileset = [file for file in glob.glob(location + "**/*.wav", recursive=True)]

# Loop to call function to convert audio files to text
for file in fileset:
    #run_speech_to_text_small_audio_files(file)
    speech_recognize_continuous_from_file(file)
    print(file)

print ("####################################################################################")
print ("PROGRAM END")
print ("####################################################################################")
print ("Thank you for using this code")
# Out:
# ####################################################################################
# PROGRAM START
# ####################################################################################
# SESSION STARTED: SessionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa)
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=b34cdfaf58e0499c85c651666241aa16, text="content", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=c9e395cd28764b28bf5d71d8a135b2b4, text="content like", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=f96726191aff49aeac5571fea0183768, text="content like data", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=030802062a47401e9253fb8459df1e0d, text="content like data models", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=5cbb3a2615834a618cf96d98173ab9fd, text="content like data models tests", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=0ea150d2270e4d569b4861a36de56bf0, text="content like data models tests and", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=e9736b8a79124642b766da4d10e70bdb, text="content like data models tests and endpoints", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=81f620d0cdcd42bf85807da996330aa3, text="content like data models tests and endpoints are", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=3b2713ab1802424980488ffaacb1cf9d, text="content like data models tests and endpoints are organized", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=4483d81f4eee4d028ed896569b4d5eda, text="content like data models tests and endpoints are organized into", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=13f839e5342b445abc0ead97e86f5dfa, text="content like data models tests and endpoints are organized into projects", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=4e6c2c95676b401d8949116dc0e34824, text="content like data models tests and endpoints are organized into projects in", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=b057cce31eaf463cb173e22e662976ae, text="content like data models tests and endpoints are organized into projects in the", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=ab991498c569424fb052642536cb70e9, text="content like data models tests and endpoints are organized into projects in the customs", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=10dfe01b707e4712a09d40e6f1a42fe8, text="content like data models tests and endpoints are organized into projects in the custom speech", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=7d7052af12de4218b4e6957949c5f7a6, text="content like data models tests and endpoints are organized into projects in the custom speech portal", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=d8db3ae396d743dabd6387ad2e867b82, text="content like data models tests and endpoints are organized into projects in the custom speech portal each", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=2292b469becc45ba97003737b2fe9014, text="content like data models tests and endpoints are organized into projects in the custom speech portal each project", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=94f4322b2774434698e08342cb42d11c, text="content like data models tests and endpoints are organized into projects in the custom speech portal each project is", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=9c091db17195493688a229cdd147f829, text="content like data models tests and endpoints are organized into projects in the custom speech portal each project is specific to a", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=a6359697f5604192ae46688c919a201b, text="content like data models tests and endpoints are organized into projects in the custom speech portal each project is specific to a domain", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=76a1beed0ae5441caeeb82e849c021f8, text="content like data models tests and endpoints are organized into projects in the custom speech portal each project is specific to a domain and", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=6e0aa6cc9c2743debc43e38fcb47ca53, text="content like data models tests and endpoints are organized into projects in the custom speech portal each project is specific to a domain and country", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=f6723fde5f47484a9082b5b4b2ef5d45, text="content like data models tests and endpoints are organized into projects in the custom speech portal each project is specific to a domain and country slash", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=e2e31e7a9fd642b99226fe0022674e18, text="content like data models tests and endpoints are organized into projects in the custom speech portal each project is specific to a domain and country slash language", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=c98ab133d2074b48aabdd3d44fb117f0, text="content like data models tests and endpoints are organized into projects in the custom speech portal each project is specific to a domain and country slash language for", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=68d2d58378f34519b34c60e2ef845710, text="content like data models tests and endpoints are organized into projects in the custom speech portal each project is specific to a domain and country slash language for example", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=87ce9dea982949c5af962f8c0b842bdc, text="content like data models tests and endpoints are organized into projects in the custom speech portal each project is specific to a domain and country slash language for example you", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=3f27f50277dc4fcaaf507be2dca437eb, text="content like data models tests and endpoints are organized into projects in the custom speech portal each project is specific to a domain and country slash language for example you make", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=703d3a6805994dd983390295f204a072, text="content like data models tests and endpoints are organized into projects in the custom speech portal each project is specific to a domain and country slash language for example you may create a", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=35a338b8d86a4cbbaf83e4cad2d3de8c, text="content like data models tests and endpoints are organized into projects in the custom speech portal each project is specific to a domain and country slash language for example you may create a project", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=0eff805bb9e741009be31688690e40d5, text="content like data models tests and endpoints are organized into projects in the custom speech portal each project is specific to a domain and country slash language for example you may create a project for", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=768dba8066a0472dad1d78c65e49080c, text="content like data models tests and endpoints are organized into projects in the custom speech portal each project is specific to a domain and country slash language for example you may create a project for call", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=9196f57f72cb4cbca64a0185433917b8, text="content like data models tests and endpoints are organized into projects in the custom speech portal each project is specific to a domain and country slash language for example you may create a project for call centers", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=c73a99dd3b92432eb7a5106ca6782f6a, text="content like data models tests and endpoints are organized into projects in the custom speech portal each project is specific to a domain and country slash language for example you may create a project for call centers that", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=e7c2e3e04961486290d10ec19fff30c3, text="content like data models tests and endpoints are organized into projects in the custom speech portal each project is specific to a domain and country slash language for example you may create a project for call centers that using", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=179884065f9c4878a7df8f7baac6774b, text="content like data models tests and endpoints are organized into projects in the custom speech portal each project is specific to a domain and country slash language for example you may create a project for call centers that use", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=e5fc9f18de694d418e379a2c025639ca, text="content like data models tests and endpoints are organized into projects in the custom speech portal each project is specific to a domain and country slash language for example you may create a project for call centers that use english in", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=461654e10fd946068e3d75a9bc88e93f, text="content like data models tests and endpoints are organized into projects in the custom speech portal each project is specific to a domain and country slash language for example you may create a project for call centers that use english in the", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=7faf4ad3c9f341de97e9b7ff778d7ec8, text="content like data models tests and endpoints are organized into projects in the custom speech portal each project is specific to a domain and country slash language for example you may create a project for call centers that use english in the united", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=863901d1812f497a8093dce6e3a4e057, text="content like data models tests and endpoints are organized into projects in the custom speech portal each project is specific to a domain and country slash language for example you may create a project for call centers that use english in the united states dot", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=3f734559df284320a5d32a53cfc62795, text="content like data models tests and endpoints are organized into projects in the custom speech portal each project is specific to a domain and country slash language for example you may create a project for call centers that use english in the united states", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=ea79fb46f7d1473d8dc983a5aeb5069f, text="content like data models tests and endpoints are organized into projects in the custom speech portal each project is specific to a domain and country slash language for example you may create a project for call centers that use english in the united states to create", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=4101d46d0b8a410986dd1d8c7746bffd, text="content like data models tests and endpoints are organized into projects in the custom speech portal each project is specific to a domain and country slash language for example you may create a project for call centers that use english in the united states to create your", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=fa1a8bad88cf40b79605364c25a8c8fb, text="content like data models tests and endpoints are organized into projects in the custom speech portal each project is specific to a domain and country slash language for example you may create a project for call centers that use english in the united states to create your first", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=499e8314c68a456faddc9975b613227c, text="content like data models tests and endpoints are organized into projects in the custom speech portal each project is specific to a domain and country slash language for example you may create a project for call centers that use english in the united states to create your first project", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=267acaf070a24d729f1d00d4821c8938, text="content like data models tests and endpoints are organized into projects in the custom speech portal each project is specific to a domain and country slash language for example you may create a project for call centers that use english in the united states to create your first project select the", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=834ff594a23141068d062e38f0d3d0a8, text="content like data models tests and endpoints are organized into projects in the custom speech portal each project is specific to a domain and country slash language for example you may create a project for call centers that use english in the united states to create your first project select the speech to", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=89c8c448bda346cfa65dee7f162e6556, text="content like data models tests and endpoints are organized into projects in the custom speech portal each project is specific to a domain and country slash language for example you may create a project for call centers that use english in the united states to create your first project select the speech to text", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=6f68cadfc96043f98a6d00b8d08aa90c, text="content like data models tests and endpoints are organized into projects in the custom speech portal each project is specific to a domain and country slash language for example you may create a project for call centers that use english in the united states to create your first project select the speech to text slash custom", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=587b5fb682614b7ba4ab5d42611ef54b, text="content like data models tests and endpoints are organized into projects in the custom speech portal each project is specific to a domain and country slash language for example you may create a project for call centers that use english in the united states to create your first project select the speech to text slash custom speech", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=b2f9e0ed77994545ad3d059295fdac6f, text="content like data models tests and endpoints are organized into projects in the custom speech portal each project is specific to a domain and country slash language for example you may create a project for call centers that use english in the united states to create your first project select the speech to text slash custom speech then", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=66fcfc6297074553b59d829b07142d0d, text="content like data models tests and endpoints are organized into projects in the custom speech portal each project is specific to a domain and country slash language for example you may create a project for call centers that use english in the united states to create your first project select the speech to text slash custom speech then click", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=d1dbc621b273480ba81ac8d8581ef9e0, text="content like data models tests and endpoints are organized into projects in the custom speech portal each project is specific to a domain and country slash language for example you may create a project for call centers that use english in the united states to create your first project select the speech to text slash custom speech then click new", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=3fe88861a42044f583618463ac09bc39, text="content like data models tests and endpoints are organized into projects in the custom speech portal each project is specific to a domain and country slash language for example you may create a project for call centers that use english in the united states to create your first project select the speech to text slash custom speech then click new project", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=f9bd643f10744c6396f5ae08cb98cbe1, text="content like data models tests and endpoints are organized into projects in the custom speech portal each project is specific to a domain and country slash language for example you may create a project for call centers that use english in the united states to create your first project select the speech to text slash custom speech then click new project follow the", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=2abb49da4abb472e8621fafe8b814257, text="content like data models tests and endpoints are organized into projects in the custom speech portal each project is specific to a domain and country slash language for example you may create a project for call centers that use english in the united states to create your first project select the speech to text slash custom speech then click new project follow the instructions", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=142a80501d124f3e92c3fa3bcdfe9843, text="content like data models tests and endpoints are organized into projects in the custom speech portal each project is specific to a domain and country slash language for example you may create a project for call centers that use english in the united states to create your first project select the speech to text slash custom speech then click new project follow the instructions provided", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=e1f7d7eb902445eabfd206d020ba57dd, text="content like data models tests and endpoints are organized into projects in the custom speech portal each project is specific to a domain and country slash language for example you may create a project for call centers that use english in the united states to create your first project select the speech to text slash custom speech then click new project follow the instructions provided by the", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=c3c54e173b8a4e5fbf5ba4729fa933dc, text="content like data models tests and endpoints are organized into projects in the custom speech portal each project is specific to a domain and country slash language for example you may create a project for call centers that use english in the united states to create your first project select the speech to text slash custom speech then click new project follow the instructions provided by the wizard", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=0f55759735fb4b5ba9d5d6b2fbbd33a7, text="content like data models tests and endpoints are organized into projects in the custom speech portal each project is specific to a domain and country slash language for example you may create a project for call centers that use english in the united states to create your first project select the speech to text slash custom speech then click new project follow the instructions provided by the wizard to", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=88e3a9c54d514c32b4af604e8379aadf, text="content like data models tests and endpoints are organized into projects in the custom speech portal each project is specific to a domain and country slash language for example you may create a project for call centers that use english in the united states to create your first project select the speech to text slash custom speech then click new project follow the instructions provided by the wizard to create", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=a53385b85fe2464986ca16f5f7cc4cbd, text="content like data models tests and endpoints are organized into projects in the custom speech portal each project is specific to a domain and country slash language for example you may create a project for call centers that use english in the united states to create your first project select the speech to text slash custom speech then click new project follow the instructions provided by the wizard to create your", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=07c57190db824eedaea670d8cf946e1b, text="content like data models tests and endpoints are organized into projects in the custom speech portal each project is specific to a domain and country slash language for example you may create a project for call centers that use english in the united states to create your first project select the speech to text slash custom speech then click new project follow the instructions provided by the wizard to create your project", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=4b11babe4f274430a7d50f7d16866fd1, text="content like data models tests and endpoints are organized into projects in the custom speech portal each project is specific to a domain and country slash language for example you may create a project for call centers that use english in the united states to create your first project select the speech to text slash custom speech then click new project follow the instructions provided by the wizard to create your project after", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=cf5c97269a5f44c88954ee4763189920, text="content like data models tests and endpoints are organized into projects in the custom speech portal each project is specific to a domain and country slash language for example you may create a project for call centers that use english in the united states to create your first project select the speech to text slash custom speech then click new project follow the instructions provided by the wizard to create your project after you", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=fa0525f9cd1e4f198df48baa0546b87e, text="content like data models tests and endpoints are organized into projects in the custom speech portal each project is specific to a domain and country slash language for example you may create a project for call centers that use english in the united states to create your first project select the speech to text slash custom speech then click new project follow the instructions provided by the wizard to create your project after you've", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=77641d3221e84bd9aa6911f309029b30, text="content like data models tests and endpoints are organized into projects in the custom speech portal each project is specific to a domain and country slash language for example you may create a project for call centers that use english in the united states to create your first project select the speech to text slash custom speech then click new project follow the instructions provided by the wizard to create your project after you've created", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=2ef88a39d7364ffcbb37621ec3bad844, text="content like data models tests and endpoints are organized into projects in the custom speech portal each project is specific to a domain and country slash language for example you may create a project for call centers that use english in the united states to create your first project select the speech to text slash custom speech then click new project follow the instructions provided by the wizard to create your project after you've created a", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=8441270c45854050988615f03f583cdd, text="content like data models tests and endpoints are organized into projects in the custom speech portal each project is specific to a domain and country slash language for example you may create a project for call centers that use english in the united states to create your first project select the speech to text slash custom speech then click new project follow the instructions provided by the wizard to create your project after you've created a project", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=8db0e4c07df34ca09078efe14251cc26, text="content like data models tests and endpoints are organized into projects in the custom speech portal each project is specific to a domain and country slash language for example you may create a project for call centers that use english in the united states to create your first project select the speech to text slash custom speech then click new project follow the instructions provided by the wizard to create your project after you've created a project you should", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=03476ca0553b480faee69e51b4022582, text="content like data models tests and endpoints are organized into projects in the custom speech portal each project is specific to a domain and country slash language for example you may create a project for call centers that use english in the united states to create your first project select the speech to text slash custom speech then click new project follow the instructions provided by the wizard to create your project after you've created a project you should see", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=31222c7dac7a4d7bb7a3d7f3f11f0ed6, text="content like data models tests and endpoints are organized into projects in the custom speech portal each project is specific to a domain and country slash language for example you may create a project for call centers that use english in the united states to create your first project select the speech to text slash custom speech then click new project follow the instructions provided by the wizard to create your project after you've created a project you should see 4", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=133c540a777145c387f3571c7a8d88d8, text="content like data models tests and endpoints are organized into projects in the custom speech portal each project is specific to a domain and country slash language for example you may create a project for call centers that use english in the united states to create your first project select the speech to text slash custom speech then click new project follow the instructions provided by the wizard to create your project after you've created a project you should see four tabs", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=884ba9fe0af447c58b40daf73a9753e0, text="content like data models tests and endpoints are organized into projects in the custom speech portal each project is specific to a domain and country slash language for example you may create a project for call centers that use english in the united states to create your first project select the speech to text slash custom speech then click new project follow the instructions provided by the wizard to create your project after you've created a project you should see four tabs data", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=2e611bd9531c4b5c97924777dfa77449, text="content like data models tests and endpoints are organized into projects in the custom speech portal each project is specific to a domain and country slash language for example you may create a project for call centers that use english in the united states to create your first project select the speech to text slash custom speech then click new project follow the instructions provided by the wizard to create your project after you've created a project you should see four tabs data testing", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=72acc82bd5744fc995c23350af2a95da, text="content like data models tests and endpoints are organized into projects in the custom speech portal each project is specific to a domain and country slash language for example you may create a project for call centers that use english in the united states to create your first project select the speech to text slash custom speech then click new project follow the instructions provided by the wizard to create your project after you've created a project you should see four tabs data testing training", reason=ResultReason.RecognizingSpeech))
# RECOGNIZED: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=adb4f1bf8c6d429e96059e1a5c94d335, text="Content like data models, tests and endpoints are organized into projects in the custom Speech portal. Each project is specific to a domain in country slash language. For example, you may create a project for call centers that use English in the United States to create your first project, select the speech to text slash custom speech, then click new project. Follow the instructions provided by the Wizard to create your project. After you've created a project, you should see four tabs. Data testing training.", reason=ResultReason.RecognizedSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=e49ba3ae593c400da779835d07b559ca, text="and", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=4489c63c67084521aa150053330662ab, text="and diploid", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=e6264667715f4557a1a8cf65a3a07999, text="and employment", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=3f33623f785c472e8ba08106e490b24c, text="and employment used", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=23625475c20f454e94b50182fe96ccb9, text="and employment use the link", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=bf74ccc7cb644263ba5bfa0751d38efd, text="and employment use the links", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=7110637e09af496da4ffc6eeeb6db772, text="and employment use the links provided in", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=e8c9229cdd644452aebf3da13ec52bee, text="and employment use the links provided in next", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=bf0454dd407c49fb8bec9b46ec5fe140, text="and employment use the links provided in next steps", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=1ffd72487f764325bea8ca6199fe7e23, text="and employment use the links provided in next steps to", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=55718463962c4be6b0b74368353539b9, text="and employment use the links provided in next steps to learn how", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=61e2c779206e43ab8921e1192f581875, text="and employment use the links provided in next steps to learn how to", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=4f737982afa14795b4c1712737f82939, text="and employment use the links provided in next steps to learn how to use", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=444fb9bc2859412a96f22452ef136205, text="and employment use the links provided in next steps to learn how to use each", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=eb04f6dd558148daa9eac4a4f73da549, text="and employment use the links provided in next steps to learn how to use each tab", reason=ResultReason.RecognizingSpeech))
# RECOGNIZED: SpeechRecognitionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=b6cebf27b6184ee1aebb30a7864c7eb0, text="And eployment use the links provided in next steps to learn how to use each tab.", reason=ResultReason.RecognizedSpeech))
# CANCELED SpeechRecognitionCanceledEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=45cc37e747f44be986783d5bb133f50f, text="", reason=ResultReason.Canceled))
# CLOSING on SpeechRecognitionCanceledEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa, result=SpeechRecognitionResult(result_id=45cc37e747f44be986783d5bb133f50f, text="", reason=ResultReason.Canceled))
# SESSION STOPPED SessionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa)
# CLOSING on SessionEventArgs(session_id=7ca4b5e24c9b43edbe578db7656c9eaa)
# Printing all results:
# ["Content like data models, tests and endpoints are organized into projects in the custom Speech portal. Each project is specific to a domain in country slash language. For example, you may create a project for call centers that use English in the United States to create your first project, select the speech to text slash custom speech, then click new project. Follow the instructions provided by the Wizard to create your project. After you've created a project, you should see four tabs. Data testing training.", 'And eployment use the links provided in next steps to learn how to use each tab.']
# Audio File: data/audio1.wav converted successfully
# ####################################################################################
# data/audio1.wav
# SESSION STARTED: SessionEventArgs(session_id=f6275dd38d3b41308734ac6e4f2db8ed)
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=f6275dd38d3b41308734ac6e4f2db8ed, result=SpeechRecognitionResult(result_id=0090062caa544a4c8e1fb7651f692507, text="customs", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=f6275dd38d3b41308734ac6e4f2db8ed, result=SpeechRecognitionResult(result_id=a2bcc1ed6dc546e1b33c7a26cf551c72, text="custom", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=f6275dd38d3b41308734ac6e4f2db8ed, result=SpeechRecognitionResult(result_id=e78dc215c0d24d20a2708a7515ddeed5, text="custom speech", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=f6275dd38d3b41308734ac6e4f2db8ed, result=SpeechRecognitionResult(result_id=e18c3ea7149549d7ac45549fc4487f6b, text="custom speech provides too", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=f6275dd38d3b41308734ac6e4f2db8ed, result=SpeechRecognitionResult(result_id=1acd1ca3db16491f85b1abdd8eb0b929, text="custom speech provides tools", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=f6275dd38d3b41308734ac6e4f2db8ed, result=SpeechRecognitionResult(result_id=692871507e73400090ca5cc239704968, text="custom speech provides tools that", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=f6275dd38d3b41308734ac6e4f2db8ed, result=SpeechRecognitionResult(result_id=edd4a277319e47939db63d40d8eea0d9, text="custom speech provides tools that allow", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=f6275dd38d3b41308734ac6e4f2db8ed, result=SpeechRecognitionResult(result_id=417c49f7f5f34b4d9a9d2acf00d32285, text="custom speech provides tools that allow you", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=f6275dd38d3b41308734ac6e4f2db8ed, result=SpeechRecognitionResult(result_id=41113b07689d46fa88249ac14aac9767, text="custom speech provides tools that allow you to", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=f6275dd38d3b41308734ac6e4f2db8ed, result=SpeechRecognitionResult(result_id=e77a5eb2ec19405babc763541af05992, text="custom speech provides tools that allow you to visually", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=f6275dd38d3b41308734ac6e4f2db8ed, result=SpeechRecognitionResult(result_id=6dc8fecc8a47409dba35a4f91af40aac, text="custom speech provides tools that allow you to visually in", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=f6275dd38d3b41308734ac6e4f2db8ed, result=SpeechRecognitionResult(result_id=204608d7ab46487e87d675c2d8ff4704, text="custom speech provides tools that allow you to visually inspect the", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=f6275dd38d3b41308734ac6e4f2db8ed, result=SpeechRecognitionResult(result_id=9dfc9e955da144a483b03c7095e39e37, text="custom speech provides tools that allow you to visually inspect the recognition", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=f6275dd38d3b41308734ac6e4f2db8ed, result=SpeechRecognitionResult(result_id=805b24ef8007454bbd572b818cbede6f, text="custom speech provides tools that allow you to visually inspect the recognition quality", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=f6275dd38d3b41308734ac6e4f2db8ed, result=SpeechRecognitionResult(result_id=fe1cf8e1580145389e499be70f151614, text="custom speech provides tools that allow you to visually inspect the recognition quality of", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=f6275dd38d3b41308734ac6e4f2db8ed, result=SpeechRecognitionResult(result_id=598f0996dc0f4ba2b355a1a8838aa73d, text="custom speech provides tools that allow you to visually inspect the recognition quality of a model", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=f6275dd38d3b41308734ac6e4f2db8ed, result=SpeechRecognitionResult(result_id=a865644da193480aa1c07f8438580fb2, text="custom speech provides tools that allow you to visually inspect the recognition quality of a model by", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=f6275dd38d3b41308734ac6e4f2db8ed, result=SpeechRecognitionResult(result_id=fa7d5fe40f254cc4b4e451afd46f2442, text="custom speech provides tools that allow you to visually inspect the recognition quality of a model by comparing", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=f6275dd38d3b41308734ac6e4f2db8ed, result=SpeechRecognitionResult(result_id=8d08745381b940d38dff5fbd58c65755, text="custom speech provides tools that allow you to visually inspect the recognition quality of a model by comparing audio", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=f6275dd38d3b41308734ac6e4f2db8ed, result=SpeechRecognitionResult(result_id=e0fb94295ddf4b0fb83808728fa3ce81, text="custom speech provides tools that allow you to visually inspect the recognition quality of a model by comparing audio data", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=f6275dd38d3b41308734ac6e4f2db8ed, result=SpeechRecognitionResult(result_id=40e1cd66d67f4c869687a9d27676d49d, text="custom speech provides tools that allow you to visually inspect the recognition quality of a model by comparing audio data with the", reason=ResultReason.RecognizingSpeech))
# ...
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=478282a305234efe8655889eea2d17be, result=SpeechRecognitionResult(result_id=6ef317c571024530b47f467cfe8a4730, text="batman's karate judo and jujitsu training has made him a master master of stealth and escape allowing to allowing him to", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=478282a305234efe8655889eea2d17be, result=SpeechRecognitionResult(result_id=3ef891ffccc64931a95e4250aadfa03e, text="batman's karate judo and jujitsu training has made him a master master of stealth and escape allowing to allowing him to appear", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=478282a305234efe8655889eea2d17be, result=SpeechRecognitionResult(result_id=ee85cd63e9514a619e2d0ca3e59cb9cb, text="batman's karate judo and jujitsu training has made him a master master of stealth and escape allowing to allowing him to appear and", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=478282a305234efe8655889eea2d17be, result=SpeechRecognitionResult(result_id=01c0c81d953849769d9efaebc8971b5b, text="batman's karate judo and jujitsu training has made him a master master of stealth and escape allowing to allowing him to appear and disappear", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=478282a305234efe8655889eea2d17be, result=SpeechRecognitionResult(result_id=c91c3dfeea1e4d1ba1b0b608ef311fd8, text="batman's karate judo and jujitsu training has made him a master master of stealth and escape allowing to allowing him to appear and disappear at", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=478282a305234efe8655889eea2d17be, result=SpeechRecognitionResult(result_id=2281cafe1f0e4971ba3463b742df3898, text="batman's karate judo and jujitsu training has made him a master master of stealth and escape allowing to allowing him to appear and disappear at will", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=478282a305234efe8655889eea2d17be, result=SpeechRecognitionResult(result_id=ecf9e7c040a64a4c9b2af38922b47600, text="batman's karate judo and jujitsu training has made him a master master of stealth and escape allowing to allowing him to appear and disappear at will and", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=478282a305234efe8655889eea2d17be, result=SpeechRecognitionResult(result_id=28049a0fd0434390bfc4672c46350685, text="batman's karate judo and jujitsu training has made him a master master of stealth and escape allowing to allowing him to appear and disappear at will and to", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=478282a305234efe8655889eea2d17be, result=SpeechRecognitionResult(result_id=ee0517037cec454d81e1b51f56a529cc, text="batman's karate judo and jujitsu training has made him a master master of stealth and escape allowing to allowing him to appear and disappear at will and to break free", reason=ResultReason.RecognizingSpeech))
# RECOGNIZED: SpeechRecognitionEventArgs(session_id=478282a305234efe8655889eea2d17be, result=SpeechRecognitionResult(result_id=5a0a8df01991435ead7ece5c3de85f27, text="Batman's karate, judo and jujitsu training has made him a master master of Stealth and Escape, allowing to allowing him to appear and disappear at will and to break free.", reason=ResultReason.RecognizedSpeech))
# RECOGNIZED: SpeechRecognitionEventArgs(session_id=478282a305234efe8655889eea2d17be, result=SpeechRecognitionResult(result_id=3743ca6856254ee8b829fbb33953c8a9, text="", reason=ResultReason.RecognizedSpeech))
# CANCELED SpeechRecognitionCanceledEventArgs(session_id=478282a305234efe8655889eea2d17be, result=SpeechRecognitionResult(result_id=93daeda896ce4049ba3d70422e1f1c50, text="", reason=ResultReason.Canceled))
# CLOSING on SpeechRecognitionCanceledEventArgs(session_id=478282a305234efe8655889eea2d17be, result=SpeechRecognitionResult(result_id=93daeda896ce4049ba3d70422e1f1c50, text="", reason=ResultReason.Canceled))
# SESSION STOPPED SessionEventArgs(session_id=478282a305234efe8655889eea2d17be)
# CLOSING on SessionEventArgs(session_id=478282a305234efe8655889eea2d17be)
# Printing all results:
# ["Skills and abilities. Batman has no inherent superpowers. He relies on his own scientific knowledge. Detective skills and athletic prowess. In the stories, Batman is regarded as one of the world's greatest detective, if not the world's greatest crime solver. Batman has been repeatedly described as having genius level intellect. One of the greatest martial artists in the DC Universe.", 'And having peak human physical conditioning, he has traveled the world, acquiring the skills needed to aid his crusade against crime.', 'His knowledge and expertise in almost every discipline known to man is nearly unparalleled by any other character in the universe.', "Batman's inexhaustible wealth allows him to access advanced technology as a proficient scientist, is able to use and modify those technologies to his advantage.", 'Batman describes Superman as the most dangerous man on Earth, able to defeat a team of superpowered extraterrestrials by himself in order to rescue his imprisoned teammates.', 'In the first storyline, Superman also considers Batman to be one of the most brilliant minds on the planet.', 'Batman has the ability to function under great physical pain and withstand mind control. He is a master of disguise, Multilingual and an expert in espionage, often gathering information under different identities.', "Batman's karate, judo and jujitsu training has made him a master master of Stealth and Escape, allowing to allowing him to appear and disappear at will and to break free.", '']
# Audio File: data/batman.wav converted successfully
# ####################################################################################
# data/batman.wav
# SESSION STARTED: SessionEventArgs(session_id=0de596a590f34fe7b3dee6b94cf13f86)
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=0de596a590f34fe7b3dee6b94cf13f86, result=SpeechRecognitionResult(result_id=52da051a8d424a42b7b5f00145d0fb37, text="hello", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=0de596a590f34fe7b3dee6b94cf13f86, result=SpeechRecognitionResult(result_id=05101c1fcc744bb9882e2072fb3ebd6b, text="hello i'm", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=0de596a590f34fe7b3dee6b94cf13f86, result=SpeechRecognitionResult(result_id=31cc417d42db40479e9513faa73f1721, text="hello i'm testing", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=0de596a590f34fe7b3dee6b94cf13f86, result=SpeechRecognitionResult(result_id=24ef65156aff466880dd59b93adda443, text="hello i'm testing this", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=0de596a590f34fe7b3dee6b94cf13f86, result=SpeechRecognitionResult(result_id=d5afc3be77c64ca68bdc53df41aa4ed5, text="hello i'm testing the speech to", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=0de596a590f34fe7b3dee6b94cf13f86, result=SpeechRecognitionResult(result_id=b0612143f5ee417787a231a98c36daff, text="hello i'm testing the speech to text", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=0de596a590f34fe7b3dee6b94cf13f86, result=SpeechRecognitionResult(result_id=194f2e0ea617445da27b1924fb7a6818, text="hello i'm testing the speech to text API", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=0de596a590f34fe7b3dee6b94cf13f86, result=SpeechRecognitionResult(result_id=f27bd1d9db8d4f01a5c94352c9cb6880, text="hello i'm testing the speech to text API from", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=0de596a590f34fe7b3dee6b94cf13f86, result=SpeechRecognitionResult(result_id=9a692b70e3dd47dab65c7a464e29ac68, text="hello i'm testing the speech to text API from microsoft", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=0de596a590f34fe7b3dee6b94cf13f86, result=SpeechRecognitionResult(result_id=8b0a0fb15bea4c42966f0497e0660433, text="hello i'm testing the speech to text API from microsoft this is", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=0de596a590f34fe7b3dee6b94cf13f86, result=SpeechRecognitionResult(result_id=2816d94ff13a4e06859e88f36100aaa6, text="hello i'm testing the speech to text API from microsoft this is kyle", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=0de596a590f34fe7b3dee6b94cf13f86, result=SpeechRecognitionResult(result_id=ed9a3de674cd4350925768273f860690, text="hello i'm testing the speech to text API from microsoft this is kyle i", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=0de596a590f34fe7b3dee6b94cf13f86, result=SpeechRecognitionResult(result_id=c50cc92dc6d3461da16bb622e698daca, text="hello i'm testing the speech to text API from microsoft this is kyle i would", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=0de596a590f34fe7b3dee6b94cf13f86, result=SpeechRecognitionResult(result_id=b89b23fb64b049959f07babdf2e5f4ca, text="hello i'm testing the speech to text API from microsoft this is kyle i would like to", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=0de596a590f34fe7b3dee6b94cf13f86, result=SpeechRecognitionResult(result_id=57d11e597c814c868ea1121bf761f43f, text="hello i'm testing the speech to text API from microsoft this is kyle i would like to try", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=0de596a590f34fe7b3dee6b94cf13f86, result=SpeechRecognitionResult(result_id=1c67e00892134f5d883378efe1a3ad96, text="hello i'm testing the speech to text API from microsoft this is kyle i would like to try i'm", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=0de596a590f34fe7b3dee6b94cf13f86, result=SpeechRecognitionResult(result_id=e57281e325b64cc19d6686ffcefc004e, text="hello i'm testing the speech to text API from microsoft this is kyle i would like to try i'm trying to", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=0de596a590f34fe7b3dee6b94cf13f86, result=SpeechRecognitionResult(result_id=6abe137fe46744be8fec19a70ae688e2, text="hello i'm testing the speech to text API from microsoft this is kyle i would like to try i'm trying to save", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=0de596a590f34fe7b3dee6b94cf13f86, result=SpeechRecognitionResult(result_id=829fc1a092534b82a92a0223c29de702, text="hello i'm testing the speech to text API from microsoft this is kyle i would like to try i'm trying to save this", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=0de596a590f34fe7b3dee6b94cf13f86, result=SpeechRecognitionResult(result_id=3f87f27634fa4962be689d9eacd6e565, text="hello i'm testing the speech to text API from microsoft this is kyle i would like to try i'm trying to save this is", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=0de596a590f34fe7b3dee6b94cf13f86, result=SpeechRecognitionResult(result_id=83aa7bb584354ffcbd07a86f48c69808, text="hello i'm testing the speech to text API from microsoft this is kyle i would like to try i'm trying to save this as a", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=0de596a590f34fe7b3dee6b94cf13f86, result=SpeechRecognitionResult(result_id=dd38cd28772442bc92331d101af68103, text="hello i'm testing the speech to text API from microsoft this is kyle i would like to try i'm trying to save this as a audio file", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=0de596a590f34fe7b3dee6b94cf13f86, result=SpeechRecognitionResult(result_id=d0447dc801064facb74ea6ad282e43b2, text="hello i'm testing the speech to text API from microsoft this is kyle i would like to try i'm trying to save this as a audio file thank", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=0de596a590f34fe7b3dee6b94cf13f86, result=SpeechRecognitionResult(result_id=9cfbe67969f0480ab135b78b52480e07, text="hello i'm testing the speech to text API from microsoft this is kyle i would like to try i'm trying to save this as a audio file thank you", reason=ResultReason.RecognizingSpeech))
# RECOGNIZED: SpeechRecognitionEventArgs(session_id=0de596a590f34fe7b3dee6b94cf13f86, result=SpeechRecognitionResult(result_id=6c24eec8ec8a4bec850f5c1e6a284358, text="Hello, I'm testing the speech to text API from Microsoft. This is Kyle. I would like to try. I'm trying to save this as a audio file. Thank you.", reason=ResultReason.RecognizedSpeech))
# CANCELED SpeechRecognitionCanceledEventArgs(session_id=0de596a590f34fe7b3dee6b94cf13f86, result=SpeechRecognitionResult(result_id=612f8bf0d8fa45deb2361a140d4453e6, text="", reason=ResultReason.Canceled))
# CLOSING on SpeechRecognitionCanceledEventArgs(session_id=0de596a590f34fe7b3dee6b94cf13f86, result=SpeechRecognitionResult(result_id=612f8bf0d8fa45deb2361a140d4453e6, text="", reason=ResultReason.Canceled))
# SESSION STOPPED SessionEventArgs(session_id=0de596a590f34fe7b3dee6b94cf13f86)
# CLOSING on SessionEventArgs(session_id=0de596a590f34fe7b3dee6b94cf13f86)
# Printing all results:
# ["Hello, I'm testing the speech to text API from Microsoft. This is Kyle. I would like to try. I'm trying to save this as a audio file. Thank you."]
# Audio File: data/Recording.wav converted successfully
# ####################################################################################
# data/Recording.wav
# SESSION STARTED: SessionEventArgs(session_id=541325af514f4df6b49748039e944c44)
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=541325af514f4df6b49748039e944c44, result=SpeechRecognitionResult(result_id=d9c4f43f997c400ea025977f84b6113e, text="what's the weather", reason=ResultReason.RecognizingSpeech))
# RECOGNIZING: SpeechRecognitionEventArgs(session_id=541325af514f4df6b49748039e944c44, result=SpeechRecognitionResult(result_id=b8bb98d7684441779a24ad5dec4f91ed, text="what's the weather like", reason=ResultReason.RecognizingSpeech))
# RECOGNIZED: SpeechRecognitionEventArgs(session_id=541325af514f4df6b49748039e944c44, result=SpeechRecognitionResult(result_id=ffdc6afe234d4f239bdef9985c4b83a3, text="What's the weather like?", reason=ResultReason.RecognizedSpeech))
# CANCELED SpeechRecognitionCanceledEventArgs(session_id=541325af514f4df6b49748039e944c44, result=SpeechRecognitionResult(result_id=7b118a8c56554d338f9ba34af610c671, text="", reason=ResultReason.Canceled))
# CLOSING on SpeechRecognitionCanceledEventArgs(session_id=541325af514f4df6b49748039e944c44, result=SpeechRecognitionResult(result_id=7b118a8c56554d338f9ba34af610c671, text="", reason=ResultReason.Canceled))
# SESSION STOPPED SessionEventArgs(session_id=541325af514f4df6b49748039e944c44)
# CLOSING on SessionEventArgs(session_id=541325af514f4df6b49748039e944c44)
# Printing all results:
# ["What's the weather like?"]
# Audio File: data/whatstheweatherlike.wav converted successfully
# ####################################################################################
# data/whatstheweatherlike.wav
# ####################################################################################
# PROGRAM END
# ####################################################################################
# Thank you for using this code
